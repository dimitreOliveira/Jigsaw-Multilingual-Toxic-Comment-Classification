# %% [markdown]
# ## Dependencies

# %%
import json, warnings, shutil
from jigsaw_utility_scripts import *
from transformers import TFXLMRobertaModel, XLMRobertaConfig
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses, layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

warnings.filterwarnings("ignore")

# %% [markdown]
# ## TPU configuration

# %%
strategy, tpu = set_up_strategy()
print("REPLICAS: ", strategy.num_replicas_in_sync)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Running on TPU  grpc://10.0.0.2:8470
# REPLICAS:  8

# %% [markdown]
# # Load data

# %%
database_base_path = '/kaggle/input/jigsaw-dataset-split-toxic-roberta-base-192/'
k_fold = pd.read_csv(database_base_path + '5-fold.csv')
valid_df = pd.read_csv("/kaggle/input/jigsaw-multilingual-toxic-comment-classification/validation.csv", usecols=['comment_text', 'toxic', 'lang'])

print('Train set samples: %d' % len(k_fold))
print('Validation set samples: %d' % len(valid_df))
display(k_fold.head())


# Unzip files
# !tar -xvf /kaggle/input/jigsaw-dataset-split-toxic-roberta-base-192/fold_1.tar.gz
# !tar -xvf /kaggle/input/jigsaw-dataset-split-toxic-roberta-base-192/fold_2.tar.gz
# !tar -xvf /kaggle/input/jigsaw-dataset-split-toxic-roberta-base-192/fold_3.tar.gz
# !tar -xvf /kaggle/input/jigsaw-dataset-split-toxic-roberta-base-192/fold_4.tar.gz
# !tar -xvf /kaggle/input/jigsaw-dataset-split-toxic-roberta-base-192/fold_5.tar.gz
# Out:
# Train set samples: 121384
# Validation set samples: 8000
#    index                                       comment_text  toxic  \
# 0      6       COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK      1
# 1     12  Hey... what is it..\n@ | talk .\nWhat is it......      1
# 2     16  Bye! \n\nDon't look, come or think of comming ...      1
# 3     42  You are gay or antisemmitian? \n\nArchangel WH...      1
# 4     43           FUCK YOUR FILTHY MOTHER IN THE ASS, DRY!      1
#
#        fold_1      fold_2      fold_3      fold_4      fold_5
# 0       train       train  validation       train       train
# 1       train       train       train       train  validation
# 2       train       train       train  validation       train
# 3  validation       train       train       train       train
# 4       train  validation       train       train       train
# fold_1/
# fold_1/x_train.npy
# fold_1/y_train.npy
# fold_1/x_valid.npy
# fold_1/y_valid.npy
# fold_2/
# fold_2/x_train.npy
# fold_2/y_train.npy
# fold_2/x_valid.npy
# fold_2/y_valid.npy
# fold_3/
# fold_3/x_train.npy
# fold_3/y_train.npy
# fold_3/x_valid.npy
# fold_3/y_valid.npy

# %% [markdown]
# # Model parameters

# %%
base_path = '/kaggle/input/jigsaw-transformers/XLM-RoBERTa/'

config = {
  "MAX_LEN": 192,
  "BATCH_SIZE": 16 * strategy.num_replicas_in_sync,
  "EPOCHS": 2,
  "LEARNING_RATE": 1e-5, 
  "ES_PATIENCE": 1,
  "N_FOLDS": 3,
  "base_model_path": base_path + 'tf-xlm-roberta-base-tf_model.h5',
  "config_path": base_path + 'xlm-roberta-base-config.json'
}

with open('config.json', 'w') as json_file:
    json.dump(json.loads(json.dumps(config)), json_file)

# %% [markdown]
# # Model

# %%
module_config = XLMRobertaConfig.from_pretrained(config['config_path'], output_hidden_states=False)

def model_fn(MAX_LEN):
    input_ids = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_ids')
    attention_mask = layers.Input(shape=(MAX_LEN,), dtype=tf.int32, name='attention_mask')
    base_model = TFXLMRobertaModel.from_pretrained(config['base_model_path'], config=module_config)
    sequence_output = base_model({'input_ids': input_ids, 'attention_mask': attention_mask})
    
    last_state = sequence_output[0]
    cls_token = last_state[:, 0, :]
    
    output = layers.Dense(1, activation='sigmoid', name='output')(cls_token)
    
    model = Model(inputs=[input_ids, attention_mask], outputs=output)
    model.compile(optimizers.Adam(lr=config['LEARNING_RATE']), 
                  loss=losses.BinaryCrossentropy(), 
                  metrics=[metrics.BinaryAccuracy(), metrics.AUC()])
    
    return model

# %% [markdown]
# # Train

# %%
history_list = []

for n_fold in range(config['N_FOLDS']):
    tf.tpu.experimental.initialize_tpu_system(tpu)
    print('\nFOLD: %d' % (n_fold+1))
    # Load data
    base_data_path = 'fold_%d/' % (n_fold+1)
    x_train = np.load(base_data_path + 'x_train.npy')
    y_train = np.load(base_data_path + 'y_train.npy')
    x_valid = np.load(base_data_path + 'x_valid.npy')
    x_valid_ml = np.load(database_base_path + 'x_valid.npy')
    y_valid_ml = np.load(database_base_path + 'y_valid.npy')
    
    step_size = x_train.shape[1] // config['BATCH_SIZE']

    ### Delete data dir
    shutil.rmtree(base_data_path)

    # Train model
    model_path = 'model_fold_%d.h5' % (n_fold+1)
    es = EarlyStopping(monitor='val_loss', mode='min', patience=config['ES_PATIENCE'], 
                       restore_best_weights=True, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', mode='min', 
                                 save_best_only=True, save_weights_only=True, verbose=1)
    
    with strategy.scope():
        model = model_fn(config['MAX_LEN'])
        history = model.fit(get_training_dataset(x_train, y_train, config['BATCH_SIZE'], AUTO),
                        validation_data=(get_validation_dataset(x_valid_ml, y_valid_ml, config['BATCH_SIZE'], AUTO)),
                        callbacks=[checkpoint, es],
                        epochs=config['EPOCHS'], 
                        steps_per_epoch=step_size,
                        verbose=2).history
        
    history_list.append(history)
    
    # Make predictions
    train_preds = model.predict(get_test_dataset(x_train, config['BATCH_SIZE'], AUTO))
    valid_preds = model.predict(get_test_dataset(x_valid, config['BATCH_SIZE'], AUTO))
    valid_ml_preds = model.predict(get_test_dataset(x_valid_ml, config['BATCH_SIZE'], AUTO))
    
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'train', 'pred_%d' % (n_fold+1)] = np.round(train_preds)
    k_fold.loc[k_fold['fold_%d' % (n_fold+1)] == 'validation', 'pred_%d' % (n_fold+1)] = np.round(valid_preds)
    valid_df['pred_%d' % (n_fold+1)] = np.round(valid_ml_preds)
# Out:
# FOLD: 1
# Train for 758 steps, validate for 62 steps
# Epoch 1/2
#
# Epoch 00001: val_loss improved from inf to 0.41201, saving model to model_fold_1.h5
# 758/758 - 215s - loss: 0.0653 - binary_accuracy: 0.9772 - auc: 0.9953 - val_loss: 0.4120 - val_binary_accuracy: 0.8429 - val_auc: 0.8088
# Epoch 2/2
#
# Epoch 00002: val_loss did not improve from 0.41201
# Restoring model weights from the end of the best epoch.
# 758/758 - 145s - loss: 0.0437 - binary_accuracy: 0.9861 - auc: 0.9967 - val_loss: 0.5307 - val_binary_accuracy: 0.8238 - val_auc: 0.8919
# Epoch 00002: early stopping
#
# FOLD: 2
# Train for 758 steps, validate for 62 steps
# Epoch 1/2
#
# Epoch 00001: val_loss improved from inf to 0.78014, saving model to model_fold_2.h5
# 758/758 - 203s - loss: 0.0691 - binary_accuracy: 0.9673 - auc_1: 0.9933 - val_loss: 0.7801 - val_binary_accuracy: 0.2477 - val_auc_1: 0.8086
# Epoch 2/2
#
# Epoch 00002: val_loss improved from 0.78014 to 0.46590, saving model to model_fold_2.h5
# 758/758 - 141s - loss: 0.0410 - binary_accuracy: 0.9844 - auc_1: 0.9971 - val_loss: 0.4659 - val_binary_accuracy: 0.8598 - val_auc_1: 0.8911
#
# FOLD: 3
# Train for 758 steps, validate for 62 steps
# Epoch 1/2
#
# Epoch 00001: val_loss improved from inf to 0.48326, saving model to model_fold_3.h5
# 758/758 - 204s - loss: 0.0592 - binary_accuracy: 0.9798 - auc_2: 0.9953 - val_loss: 0.4833 - val_binary_accuracy: 0.8019 - val_auc_2: 0.8180
# Epoch 2/2
#
# Epoch 00002: val_loss did not improve from 0.48326
# Restoring model weights from the end of the best epoch.
# 758/758 - 144s - loss: 0.0442 - binary_accuracy: 0.9854 - auc_2: 0.9962 - val_loss: 0.9861 - val_binary_accuracy: 0.5173 - val_auc_2: 0.8834
# Epoch 00002: early stopping

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    plot_metrics(history_list[n_fold])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation

# %%
display(evaluate_model(k_fold, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col0 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col1 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col2 {
#             color:  red;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col3 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col4 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col5 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col6 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col7 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col8 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col0 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col1 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col2 {
#             color:  red;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col3 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col4 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col5 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col6 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col7 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col8 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row2_col2 {
#             color:  red;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row2_col4 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row2_col5 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row2_col6 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row2_col7 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row2_col8 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row3_col0 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row3_col1 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row3_col2 {
#             color:  red;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row3_col3 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row3_col4 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row3_col5 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row3_col6 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row3_col7 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row3_col8 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row4_col0 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row4_col1 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row4_col2 {
#             color:  red;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row4_col3 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row4_col4 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row4_col5 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row4_col6 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row4_col7 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row4_col8 {
#             color:  black;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row5_col0 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row5_col1 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row5_col2 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row5_col3 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row5_col4 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row5_col5 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row5_col6 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row5_col7 {
#             color:  green;
#         }    #T_1b08b90c_81bd_11ea_9115_0242ac130202row5_col8 {
#             color:  green;
#         }</style><table id="T_1b08b90c_81bd_11ea_9115_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Train</th>        <th class="col_heading level0 col1" >Valid</th>        <th class="col_heading level0 col2" >Var</th>        <th class="col_heading level0 col3" >Train_fold_1</th>        <th class="col_heading level0 col4" >Valid_fold_1</th>        <th class="col_heading level0 col5" >Train_fold_2</th>        <th class="col_heading level0 col6" >Valid_fold_2</th>        <th class="col_heading level0 col7" >Train_fold_3</th>        <th class="col_heading level0 col8" >Valid_fold_3</th>    </tr>    <tr>        <th class="index_name level0" >Metric</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b08b90c_81bd_11ea_9115_0242ac130202level0_row0" class="row_heading level0 row0" >ROC AUC</th>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col0" class="data row0 col0" >0.852749</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col1" class="data row0 col1" >0.852973</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col2" class="data row0 col2" >-0.000224078</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col3" class="data row0 col3" >0.818394</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col4" class="data row0 col4" >0.817865</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col5" class="data row0 col5" >0.907067</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col6" class="data row0 col6" >0.90852</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col7" class="data row0 col7" >0.832786</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row0_col8" class="data row0 col8" >0.832533</td>
#             </tr>
#             <tr>
#                         <th id="T_1b08b90c_81bd_11ea_9115_0242ac130202level0_row1" class="row_heading level0 row1" >Accuracy</th>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col0" class="data row1 col0" >0.839812</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col1" class="data row1 col1" >0.84048</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col2" class="data row1 col2" >-0.000667575</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col3" class="data row1 col3" >0.862018</td>
#                         <td id="T_1b08b90c_81bd_11ea_9115_0242ac130202row1_col4" class="data row1 col4" >0.860115</td>
#                         <td id="T_1b08b90c_81bd_11ea_9

# %% [markdown]
# # Confusion matrix

# %%
for n_fold in range(config['N_FOLDS']):
    print('Fold: %d' % (n_fold+1))
    train_set = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'train']
    validation_set = k_fold[k_fold['fold_%d' % (n_fold+1)] == 'validation'] 
    plot_confusion_matrix(train_set['toxic'], train_set['pred_%d' % (n_fold+1)], 
                          validation_set['toxic'], validation_set['pred_%d' % (n_fold+1)])
# Out:
# Fold: 1
# Fold: 2
# Fold: 3

# %% [markdown]
# # Model evaluation by language

# %%
display(evaluate_model_lang(valid_df, config['N_FOLDS']).style.applymap(color_map))
# Out:
# <style  type="text/css" >
#     #T_1d7057ea_81bd_11ea_9115_0242ac130202row0_col0 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row0_col1 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row0_col2 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row0_col3 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row1_col0 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row1_col1 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row1_col2 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row1_col3 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row2_col0 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row2_col1 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row2_col2 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row2_col3 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row3_col0 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row3_col1 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row3_col2 {
#             color:  black;
#         }    #T_1d7057ea_81bd_11ea_9115_0242ac130202row3_col3 {
#             color:  black;
#         }</style><table id="T_1d7057ea_81bd_11ea_9115_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Mean</th>        <th class="col_heading level0 col1" >Fold_1</th>        <th class="col_heading level0 col2" >Fold_2</th>        <th class="col_heading level0 col3" >Fold_3</th>    </tr>    <tr>        <th class="index_name level0" >Lang / ROC AUC</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1d7057ea_81bd_11ea_9115_0242ac130202level0_row0" class="row_heading level0 row0" >Overall</th>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row0_col0" class="data row0 col0" >0.719813</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row0_col1" class="data row0 col1" >0.688318</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row0_col2" class="data row0 col2" >0.731479</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row0_col3" class="data row0 col3" >0.739642</td>
#             </tr>
#             <tr>
#                         <th id="T_1d7057ea_81bd_11ea_9115_0242ac130202level0_row1" class="row_heading level0 row1" >es</th>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row1_col0" class="data row1 col0" >0.73152</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row1_col1" class="data row1 col1" >0.703248</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row1_col2" class="data row1 col2" >0.746846</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row1_col3" class="data row1 col3" >0.744468</td>
#             </tr>
#             <tr>
#                         <th id="T_1d7057ea_81bd_11ea_9115_0242ac130202level0_row2" class="row_heading level0 row2" >it</th>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row2_col0" class="data row2 col0" >0.693632</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row2_col1" class="data row2 col1" >0.663248</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row2_col2" class="data row2 col2" >0.711308</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row2_col3" class="data row2 col3" >0.70634</td>
#             </tr>
#             <tr>
#                         <th id="T_1d7057ea_81bd_11ea_9115_0242ac130202level0_row3" class="row_heading level0 row3" >tr</th>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row3_col0" class="data row3 col0" >0.709686</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row3_col1" class="data row3 col1" >0.682906</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row3_col2" class="data row3 col2" >0.710541</td>
#                         <td id="T_1d7057ea_81bd_11ea_9115_0242ac130202row3_col3" class="data row3 col3" >0.735611</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Visualize predictions

# %%
pd.set_option('max_colwidth', 120)
display(k_fold[['comment_text', 'toxic'] + [c for c in k_fold.columns if c.startswith('pred')]].head(15))
# Out:
#                                                                                                                comment_text  \
# 0                                                                              COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK
# 1   Hey... what is it..\n@ | talk .\nWhat is it... an exclusive group of some WP TALIBANS...who are good at destroying, ...
# 2                                                               Bye! \n\nDon't look, come or think of comming back! Tosser.
# 3   You are gay or antisemmitian? \n\nArchangel WHite Tiger\n\nMeow! Greetingshhh!\n\nUh, there are two ways, why you do...
# 4                                                                                  FUCK YOUR FILTHY MOTHER IN THE ASS, DRY!
# 5   I'm Sorry \n\nI'm sorry I screwed around with someones talk page.  It was very bad to do.  I know how having the tem...
# 6   GET FUCKED UP. GET FUCKEEED UP.  GOT A DRINK THAT YOU CANT PUT DOWN???/ GET FUCK UP GET FUCKED UP.  I'M FUCKED UP RI...
# 7                                 Stupid peace of shit stop deleting my stuff asshole go die and fall in a hole go to hell!
# 8                                                      =Tony Sidaway is obviously a fistfuckee. He loves an arm up his ass.
# 9   My Band Page's deletion. You thought I was gone. \n\nDeleting the comment I posted on your 'talk page' does not dele...
# 10  Why can't you believe how fat Artie is? Did you see him on his recent appearence on the Tonight Show with Jay Leno? ...
# 11  All of my edits are good.  Cunts like you who revert good edits because you're too stupid to understand how to write...
# 12                                                       Hi! I am back again!\nLast warning!\nStop undoing my edits or die!
# 13                                                Would you both shut up, you don't run wikipedia, especially a stupid kid.
# 14                                                                               A pair of jew-hating weiner nazi schmucks.
#
#     toxic  pred_1  pred_2  pred_3
# 0       1     0.0     1.0     1.0
# 1       1     0.0     0.0     1.0
# 2       1     1.0     0.0     1.0
# 3       1     1.0     1.0     1.0
# 4       1     1.0     1.0     1.0
# 5       1     0.0     0.0     1.0
# 6       1     1.0     1.0     1.0
# 7       1     1.0     1.0     1.0
# 8       1     1.0     1.0     1.0
# 9       1     1.0     1.0     1.0
# 10      1     1.0     1.0     1.0
# 11      1     1.0     1.0     1.0
# 12      1     1.0     0.0     1.0
# 13      1     1.0     1.0     1.0
# 14      1     1.0     1.0     1.0
