# %% [markdown]
# ## Dependencies

# %%
import os, warnings
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from transformers import TFDistilBertModel
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers, metrics, losses
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D, concatenate
from sklearn.metrics import confusion_matrix, roc_auc_score, classification_report

def seed_everything(seed=0):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'

SEED = 0
seed_everything(SEED)
warnings.filterwarnings("ignore")

# %%
# Auxiliary functions
def plot_metrics(history, metric_list):
    fig, axes = plt.subplots(len(metric_list), 1, sharex='col', figsize=(20, 18))
    axes = axes.flatten()
    
    for index, metric in enumerate(metric_list):
        axes[index].plot(history[metric], label='Train %s' % metric)
        axes[index].plot(history['val_%s' % metric], label='Validation %s' % metric)
        axes[index].legend(loc='best', fontsize=16)
        axes[index].set_title(metric)

    plt.xlabel('Epochs', fontsize=16)
    sns.despine()
    plt.show()
    
def plot_confusion_matrix(y_train, train_pred, y_valid, valid_pred, labels=[0, 1]):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))
    train_cnf_matrix = confusion_matrix(y_train, train_pred)
    validation_cnf_matrix = confusion_matrix(y_valid, valid_pred)

    train_cnf_matrix_norm = train_cnf_matrix.astype('float') / train_cnf_matrix.sum(axis=1)[:, np.newaxis]
    validation_cnf_matrix_norm = validation_cnf_matrix.astype('float') / validation_cnf_matrix.sum(axis=1)[:, np.newaxis]

    train_df_cm = pd.DataFrame(train_cnf_matrix_norm, index=labels, columns=labels)
    validation_df_cm = pd.DataFrame(validation_cnf_matrix_norm, index=labels, columns=labels)

    sns.heatmap(train_df_cm, annot=True, fmt='.2f', cmap="Blues",ax=ax1).set_title('Train')
    sns.heatmap(validation_df_cm, annot=True, fmt='.2f', cmap=sns.cubehelix_palette(8),ax=ax2).set_title('Validation')
    plt.show()

# Datasets
def get_training_dataset():
    dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    dataset = dataset.prefetch(AUTO)
    return dataset

def get_validation_dataset(repeated=False):
    dataset = tf.data.Dataset.from_tensor_slices((x_valid, y_valid))
    if repeated:
        dataset = dataset.repeat()
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    dataset = dataset.cache()
    dataset = dataset.prefetch(AUTO)
    return dataset

# Util
from tensorflow.keras import backend as K
def focal_loss(gamma=2., alpha=.2):
    def focal_loss_fixed(y_true, y_pred):
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
        return -K.mean(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1)) - K.mean((1 - alpha) * K.pow(pt_0, gamma) * K.log(1. - pt_0))
    return focal_loss_fixed

# %% [markdown]
# ## TPU configuration

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()

print("REPLICAS: ", strategy.num_replicas_in_sync)

AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Running on TPU  grpc://10.0.0.2:8470
# REPLICAS:  8

# %% [markdown]
# # Load data

# %%
dataset_base_path = '/kaggle/input/jigsaw-dataset-toxic-distilbert/'
x_train_toxic_path = dataset_base_path + 'x_train_toxic.npy'
y_train_toxic_path = dataset_base_path + 'y_train_toxic.npy'
x_valid_path = dataset_base_path + 'x_valid.npy'
y_valid_path = dataset_base_path + 'y_valid.npy'

x_train = np.load(x_train_toxic_path)
y_train = np.load(y_train_toxic_path)

x_valid = np.load(x_valid_path)
y_valid = np.load(y_valid_path)

print('Train samples %d' % len(x_train))
print('Validation samples %d' % len(x_valid))
# Out:
# Train samples 223549
# Validation samples 8000

# %% [markdown]
# # Model parameters

# %%
MAX_LEN = 512
BATCH_SIZE = 64 #64 * strategy.num_replicas_in_sync
EPOCHS = 35
LEARNING_RATE = 1e-5 # * strategy.num_replicas_in_sync
ES_PATIENCE = 6
TRAIN_STEPS = len(x_train) // BATCH_SIZE
VALIDATION_STEPS = len(x_valid) // BATCH_SIZE

base_model_path = '/kaggle/input/diltilbert-base-ml-cased-huggingface/distilbert-base-multilingual-cased-tf_model.h5'
config_path = '/kaggle/input/diltilbert-base-ml-cased-huggingface/distilbert-base-multilingual-cased-config.json'
model_path = 'model.h5'

# %% [markdown]
# # Learning rate schedule

# %%
LR_START = 0.000001
LR_MIN = 0.0000001
LR_MAX = 0.000004
LR_RAMPUP_EPOCHS = 7
LR_SUSTAIN_EPOCHS = 0
LR_EXP_DECAY = .87

def lrfn(epoch):
    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = (LR_MAX - LR_MIN) * LR_EXP_DECAY**(epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) + LR_MIN
    return lr
    
rng = [i for i in range(EPOCHS)]
y = [lrfn(x) for x in rng]

fig, ax = plt.subplots(figsize=(20, 8))
plt.plot(rng, y)
print("Learning rate schedule: {:.3g} to {:.3g} to {:.3g}".format(y[0], max(y), y[-1]))
# Out:
# Learning rate schedule: 1e-06 to 4e-06 to 1.91e-07

# %% [markdown]
# # Model

# %%
def model_fn():
    input_word_ids = Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_word_ids')
    base_model = TFDistilBertModel.from_pretrained(base_model_path, config=config_path)
    sequence_output = base_model(input_word_ids)[0]
    cls_token = sequence_output[:, 0, :]
    
    x = Dropout(0.35)(cls_token)
    output = Dense(1, activation='sigmoid', name='output')(x)
    
    model = Model(inputs=input_word_ids, outputs=output)
    model.compile(optimizers.Adam(lr=LEARNING_RATE), 
#                   loss=losses.BinaryCrossentropy(), 
                  loss=focal_loss(gamma=1.5), 
                  metrics=[metrics.BinaryAccuracy(), metrics.AUC()])
    
    return model

with strategy.scope():
    model = model_fn()
    
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_word_ids (InputLayer)  [(None, 512)]             0
# _________________________________________________________________
# tf_distil_bert_model (TFDist ((None, 512, 768),)       134734080
# _________________________________________________________________
# tf_op_layer_strided_slice (T [(None, 768)]             0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 768)               0
# _________________________________________________________________
# output (Dense)               (None, 1)                 769
# =================================================================
# Total params: 134,734,849
# Trainable params: 134,734,849
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train

# %%
STEPS_PER_EPOCH = 150 #len(x_train) // BATCH_SIZE

es = EarlyStopping(monitor='val_loss', mode='min', patience=ES_PATIENCE, 
                   restore_best_weights=True, verbose=1)
lr_callback = LearningRateScheduler(lrfn, verbose=1)

history = model.fit(x=get_training_dataset(),
                    steps_per_epoch=STEPS_PER_EPOCH,
                    validation_data=get_validation_dataset(),
#                     callbacks=[es, lr_callback],
                    callbacks=[lr_callback],
                    epochs=EPOCHS, 
                    verbose=1).history

model.save_weights(model_path)
# Out:
# Train for 150 steps, validate for 125 steps
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-06.
# Epoch 1/35
# 150/150 [==============================] - 65s 435ms/step - loss: 0.0572 - binary_accuracy: 0.8659 - auc: 0.5144 - val_loss: 0.0503 - val_binary_accuracy: 0.8463 - val_auc: 0.5299
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 1.4285714285714286e-06.
# Epoch 2/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0373 - binary_accuracy: 0.9036 - auc: 0.5713 - val_loss: 0.0487 - val_binary_accuracy: 0.8463 - val_auc: 0.6215
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 1.857142857142857e-06.
# Epoch 3/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0361 - binary_accuracy: 0.9003 - auc: 0.6373 - val_loss: 0.0460 - val_binary_accuracy: 0.8463 - val_auc: 0.6940
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 2.285714285714286e-06.
# Epoch 4/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0316 - binary_accuracy: 0.8996 - auc: 0.7797 - val_loss: 0.0490 - val_binary_accuracy: 0.8484 - val_auc: 0.7084
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 2.7142857142857144e-06.
# Epoch 5/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0265 - binary_accuracy: 0.9090 - auc: 0.8588 - val_loss: 0.0580 - val_binary_accuracy: 0.8518 - val_auc: 0.7259
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 3.142857142857143e-06.
# Epoch 6/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0231 - binary_accuracy: 0.9197 - auc: 0.8910 - val_loss: 0.0626 - val_binary_accuracy: 0.8490 - val_auc: 0.7227
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 3.5714285714285714e-06.
# Epoch 7/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0216 - binary_accuracy: 0.9245 - auc: 0.9144 - val_loss: 0.0595 - val_binary_accuracy: 0.8504 - val_auc: 0.7512
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 4e-06.
# Epoch 8/35
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0205 - binary_accuracy: 0.9296 - auc: 0.9225 - val_loss: 0.0441 - val_binary_accuracy: 0.8538 - val_auc: 0.7602
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 3.493e-06.
# Epoch 9/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0186 - binary_accuracy: 0.9377 - auc: 0.9348 - val_loss: 0.0426 - val_binary_accuracy: 0.8508 - val_auc: 0.7731
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 3.05191e-06.
# Epoch 10/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0172 - binary_accuracy: 0.9395 - auc: 0.9440 - val_loss: 0.0420 - val_binary_accuracy: 0.8485 - val_auc: 0.7798
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 2.6681616999999997e-06.
# Epoch 11/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0178 - binary_accuracy: 0.9363 - auc: 0.9481 - val_loss: 0.0416 - val_binary_accuracy: 0.8494 - val_auc: 0.7799
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 2.3343006789999994e-06.
# Epoch 12/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0164 - binary_accuracy: 0.9418 - auc: 0.9566 - val_loss: 0.0420 - val_binary_accuracy: 0.8501 - val_auc: 0.7810
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 2.04384159073e-06.
# Epoch 13/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0162 - binary_accuracy: 0.9442 - auc: 0.9565 - val_loss: 0.0439 - val_binary_accuracy: 0.8476 - val_auc: 0.7772
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 1.7911421839351001e-06.
# Epoch 14/35
# 150/150 [==============================] - 22s 143ms/step - loss: 0.0170 - binary_accuracy: 0.9369 - auc: 0.9574 - val_loss: 0.0430 - val_binary_accuracy: 0.8483 - val_auc: 0.7849
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 1.571293700023537e-06.
# Epoch 15/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0145 - binary_accuracy: 0.9482 - auc: 0.9621 - val_loss: 0.0420 - val_binary_accuracy: 0.8496 - val_auc: 0.7883
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 1.3800255190204773e-06.
# Epoch 16/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0158 - binary_accuracy: 0.9452 - auc: 0.9598 - val_loss: 0.0431 - val_binary_accuracy: 0.8480 - val_auc: 0.7864
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 1.2136222015478153e-06.
# Epoch 17/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0170 - binary_accuracy: 0.9374 - auc: 0.9593 - val_loss: 0.0473 - val_binary_accuracy: 0.8465 - val_auc: 0.7879
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 1.0688513153465993e-06.
# Epoch 18/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0200 - binary_accuracy: 0.9222 - auc: 0.9462 - val_loss: 0.0473 - val_binary_accuracy: 0.8465 - val_auc: 0.7914
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 9.429006443515411e-07.
# Epoch 19/35
# 150/150 [==============================] - 21s 140ms/step - loss: 0.0182 - binary_accuracy: 0.9307 - auc: 0.9462 - val_loss: 0.0476 - val_binary_accuracy: 0.8465 - val_auc: 0.7932
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 8.333235605858409e-07.
# Epoch 20/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0190 - binary_accuracy: 0.9253 - auc: 0.9515 - val_loss: 0.0498 - val_binary_accuracy: 0.8465 - val_auc: 0.7943
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 7.379914977096815e-07.
# Epoch 21/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0186 - binary_accuracy: 0.9289 - auc: 0.9504 - val_loss: 0.0505 - val_binary_accuracy: 0.8465 - val_auc: 0.7959
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 6.55052603007423e-07.
# Epoch 22/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0192 - binary_accuracy: 0.9268 - auc: 0.9482 - val_loss: 0.0497 - val_binary_accuracy: 0.8465 - val_auc: 0.7985
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 5.828957646164579e-07.
# Epoch 23/35
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0183 - binary_accuracy: 0.9285 - auc: 0.9529 - val_loss: 0.0488 - val_binary_accuracy: 0.8465 - val_auc: 0.7982
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 5.201193152163184e-07.
# Epoch 24/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0160 - binary_accuracy: 0.9369 - auc: 0.9637 - val_loss: 0.0437 - val_binary_accuracy: 0.8478 - val_auc: 0.8028
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 4.65503804238197e-07.
# Epoch 25/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0141 - binary_accuracy: 0.9483 - auc: 0.9664 - val_loss: 0.0474 - val_binary_accuracy: 0.8474 - val_auc: 0.7985
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 4.179883096872314e-07.
# Epoch 26/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0154 - binary_accuracy: 0.9442 - auc: 0.9653 - val_loss: 0.0453 - val_binary_accuracy: 0.8480 - val_auc: 0.7997
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 3.7664982942789134e-07.
# Epoch 27/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0150 - binary_accuracy: 0.9428 - auc: 0.9713 - val_loss: 0.0444 - val_binary_accuracy: 0.8483 - val_auc: 0.7981
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 3.4068535160226545e-07.
# Epoch 28/35
# 150/150 [==============================] - 21s 143ms/step - loss: 0.0136 - binary_accuracy: 0.9489 - auc: 0.9743 - val_loss: 0.0448 - val_binary_accuracy: 0.8481 - val_auc: 0.7981
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 3.09396255893971e-07.
# Epoch 29/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0127 - binary_accuracy: 0.9513 - auc: 0.9758 - val_loss: 0.0454 - val_binary_accuracy: 0.8486 - val_auc: 0.7963
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 2.8217474262775474e-07.
# Epoch 30/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0139 - binary_accuracy: 0.9476 - auc: 0.9710 - val_loss: 0.0451 - val_binary_accuracy: 0.8485 - val_auc: 0.7983
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 2.584920260861466e-07.
# Epoch 31/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0141 - binary_accuracy: 0.9491 - auc: 0.9695 - val_loss: 0.0447 - val_binary_accuracy: 0.8489 - val_auc: 0.7967
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 2.3788806269494755e-07.
# Epoch 32/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0133 - binary_accuracy: 0.9526 - auc: 0.9717 - val_loss: 0.0445 - val_binary_accuracy: 0.8488 - val_auc: 0.7981
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 2.1996261454460436e-07.
# Epoch 33/35
# 150/150 [==============================] - 21s 141ms/step - loss: 0.0136 - binary_accuracy: 0.9483 - auc: 0.9726 - val_loss: 0.0436 - val_binary_accuracy: 0.8489 - val_auc: 0.7986
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 2.043674746538058e-07.
# Epoch 34/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0136 - binary_accuracy: 0.9518 - auc: 0.9697 - val_loss: 0.0447 - val_binary_accuracy: 0.8488 - val_auc: 0.7962
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 1.9079970294881104e-07.
# Epoch 35/35
# 150/150 [==============================] - 21s 142ms/step - loss: 0.0143 - binary_accuracy: 0.9488 - auc: 0.9702 - val_loss: 0.0449 - val_binary_accuracy: 0.8481 - val_auc: 0.7964

# %% [markdown]
# ## Model loss graph

# %%
sns.set(style="whitegrid")
plot_metrics(history, metric_list=['loss', 'binary_accuracy', 'auc'])

# %% [markdown]
# # Model evaluation

# %%
train_pred = model.predict(get_training_dataset(), steps=TRAIN_STEPS)
valid_pred = model.predict(get_validation_dataset())
y_train = y_train[:len(train_pred)]
y_valid = y_valid[:len(valid_pred)]

print('Train set ROC AUC %.4f' % roc_auc_score(y_train, train_pred))
print(classification_report(y_train, np.round(train_pred)))
print('Validation set ROC AUC %.4f' % roc_auc_score(y_valid, valid_pred))
print(classification_report(y_valid, np.round(valid_pred)))
# Out:
# Train set ROC AUC 0.5027
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.92    202107
#          1.0       0.10      0.07      0.08     21381
#
#     accuracy                           0.85    223488
#    macro avg       0.50      0.50      0.50    223488
# weighted avg       0.83      0.85      0.84    223488
#
# Validation set ROC AUC 0.7966
#               precision    recall  f1-score   support
#
#          0.0       0.85      1.00      0.92      6770
#          1.0       0.74      0.02      0.04      1230
#
#     accuracy                           0.85      8000
#    macro avg       0.80      0.51      0.48      8000
# weighted avg       0.83      0.85      0.78      8000

# %% [markdown]
# # Confusion matrix

# %%
plot_confusion_matrix(y_train, np.round(train_pred), y_valid, np.round(valid_pred))

# %% [markdown]
# # Visualize predictions

# %%
train = pd.read_csv("/kaggle/input/jigsaw-multilingual-toxic-comment-classification/jigsaw-toxic-comment-train.csv", 
                    usecols=['comment_text', 'toxic'], nrows=10)
valid = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/validation.csv', 
                    usecols=['comment_text', 'toxic'], nrows=10)
train['pred'] = train_pred[:len(train)]
valid['pred'] = valid_pred[:len(valid)]

print('Train set')
display(train[['comment_text', 'toxic', 'pred']].head(10))
print('Validation set')
display(valid[['comment_text', 'toxic', 'pred']].head(10))
# Out:
# Train set
#                                         comment_text  toxic      pred
# 0  Explanation\nWhy the edits made under my usern...      0  0.313912
# 1  D'aww! He matches this background colour I'm s...      0  0.038988
# 2  Hey man, I'm really not trying to edit war. It...      0  0.010727
# 3  "\nMore\nI can't make any real suggestions on ...      0  0.161086
# 4  You, sir, are my hero. Any chance you remember...      0  0.073288
# 5  "\n\nCongratulations from me as well, use the ...      0  0.067660
# 6       COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK      1  0.045986
# 7  Your vandalism to the Matt Shirvington article...      0  0.060401
# 8  Sorry if the word 'nonsense' was offensive to ...      0  0.029628
# 9  alignment on this subject and which are contra...      0  0.131962
# Validation set
#                                         comment_text  toxic      pred
# 0  Este usuario ni siquiera llega al rango de    ...      0  0.080129
# 1  Il testo di questa voce pare esser scopiazzato...      0  0.045754
# 2  Vale. Sólo expongo mi pasado. Todo tiempo pasa...      1  0.076047
# 3  Bu maddenin alt başlığı olarak  uluslararası i...      0  0.109365
# 4  Belçika nın şehirlerinin yanında ilçe ve belde...      0  0.142261
# 5  güzel, zaten kaynaklandırması zor subjektif ka...      0  0.098089
# 6  No es mala idea. De hecho, yo estaba pensando ...      0  0.068982
# 7  Kod hatalarını düzeltmişsiniz,elinize sağlık ç...      0  0.169406
# 8  Levent Abi nasılsın? Hayat nasıl gidiyor? Umar...      0  0.167507
# 9  Creo que es importante que podamos reconocer a...      0  0.076357
